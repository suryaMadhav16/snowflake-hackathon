# %% [markdown]
# # Test Snowflake RAG Service Implementation
#
# This notebook tests the Snowflake service implementation for our RAG chat application.

# %%
import os
import tempfile
from snowflake_service import SnowflakeService

# Set up connection parameters (replace with your actual credentials)
# connection_params = {
#     "account": os.getenv("SNOWFLAKE_ACCOUNT"),
#     "user": os.getenv("SNOWFLAKE_USER"),
#     "password": os.getenv("SNOWFLAKE_PASSWORD"),
#     "role": os.getenv("SNOWFLAKE_ROLE"),
#     "warehouse": os.getenv("SNOWFLAKE_WAREHOUSE"),
#     "database": "RAG_CHAT_DB",
#     "schema": "RAG_CHAT_SCHEMA"
# }
connection_params = {
    "account": "blcquff-dcb49840",
    "user": "TAZ16",
    "password": "Srinijani@95",
    "role": "ACCOUNTADMIN",
    "warehouse": "COMPUTE_WH",
    "database": "RAG_CHAT_DB",
    "schema": "RAG_CHAT_SCHEMA"
}
print("Connection parameters:", connection_params)
# Out:
# Connection parameters: {'account': 'blcquff-dcb49840', 'user': 'TAZ16', 'password': 'Srinijani@95', 'role': 'ACCOUNTADMIN', 'warehouse': 'COMPUTE_WH', 'database': 'RAG_CHAT_DB', 'schema': 'RAG_CHAT_SCHEMA'}

# %% [markdown]
# ## Initialize Snowflake Service

# %%
# Initialize Snowflake service
service = SnowflakeService(connection_params)
print("Service initialized successfully!")
# Out:
# ✅ In Groundedness, input source will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Groundedness, input statement will be set to __record__.main_output or `Select.RecordOutput` .
# ✅ In Context Relevance, input question will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Context Relevance, input context will be set to __record__.main_output or `Select.RecordOutput` .
# ✅ In Answer Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Answer Relevance, input response will be set to __record__.main_output or `Select.RecordOutput` .
# instrumenting <class 'trulens.core.feedback.feedback.Feedback'> for base <class 'trulens.core.feedback.feedback.Feedback'>
# 	instrumenting __call__
# skipping base <class 'trulens.core.schema.feedback.FeedbackDefinition'> because of class
# skipping base <class 'trulens.core.utils.pyschema.WithClassInfo'> because of class
# skipping base <class 'trulens.core.utils.serial.SerialModel'> because of class
# skipping base <class 'pydantic.main.BaseModel'> because of class
# skipping base <class 'collections.abc.Hashable'> because of class
# skipping base <class 'typing.Generic'> because of class
# skipping base <class 'object'> because of class
# skipping base <class 'trulens.core.utils.pyschema.Method'> because of class
# skipping base <class 'trulens.core.utils.pyschema.FunctionOrMethod'> because of class
# skipping base <class 'trulens.core.utils.serial.SerialModel'> because of class
# skipping base <class 'pydantic.main.BaseModel'> because of class
# skipping base <class 'object'> because of class
# skipping base <class 'trulens.core.utils.pyschema.Class'> because of class
# skipping base <class 'trulens.core.utils.serial.SerialModel'> because of class
# skipping base <class 'pydantic.main.BaseModel'> because of class
# skipping base <class 'object'> because of class
# instrumenting <class 'trulens.core.feedback.feedback.Feedback'> for base <class 'trulens.core.feedback.feedback.Feedback'>
# 	instrumenting __call__
# skipping base <class 'trulens.core.schema.feedback.FeedbackDefinition'> because of class
# skipping base <class 'trulens.core.utils.pyschema.WithClassInfo'> because of class
# skipping base <class 'trulens.core.utils.serial.SerialModel'> because of class
# skipping base <class 'pydantic.main.BaseModel'> because of class
# skipping base <class 'collections.abc.Hashable'> because of class
# skipping base <class 'typing.Generic'> because of class
# skipping base <class 'object'> because of class
# skipping base <class 'trulens.core.utils.pyschema.Method'> because of class
# skipping base <class 'trulens.core.utils.pyschema.FunctionOrMethod'> because of class
# skipping base <class 'trulens.core.utils.serial.SerialModel'> because of class
# skipping base <class 'pydantic.main.BaseModel'> because of class
# skipping base <class 'object'> because of class
# skipping base <class 'trulens.core.utils.pyschema.Class'> because of class
# skipping base <class 'trulens.core.utils.serial.SerialModel'> because of class
# skipping base <class 'pydantic.main.BaseModel'> because of class
# skipping base <class 'object'> because of class
# instrumenting <class 'trulens.core.feedback.feedback.Feedback'> for base <class 'trulens.core.feedback.feedback.Feedback'>
# 	instrumenting __call__
# skipping base <class 'trulens.core.schema.feedback.FeedbackDefinition'> because of class
# skipping base <class 'trulens.core.utils.pyschema.WithClassInfo'> because of class
# skipping base <class 'trulens.core.utils.serial.SerialModel'> because of class
# skipping base <class 'pydantic.main.BaseModel'> because of class
# skipping base <class 'collections.abc.Hashable'> because of class
# skipping base <class 'typing.Generic'> because of class
# skipping base <class 'object'> because of class
# skipping base <class 'trulens.core.utils.pyschema.Method'> because of class
# skipping base <class 'trulens.core.utils.pyschema.FunctionOrMethod'> because of class
# skipping base <class 'trulens.core.utils.serial.SerialModel'> because of class
# skipping base <class 'pydantic.main.BaseModel'> because of class
# skipping base <class 'object'> because of class
# skipping base <class 'trulens.core.utils.pyschema.Class'> because of class
# skipping base <class 'trulens.core.utils.serial.SerialModel'> because of class
# skipping base <class 'pydantic.main.BaseModel'> because of class
# skipping base <class 'object'> because of class
# instrumenting <class 'snowflake_service.SnowflakeService'> for base <class 'snowflake_service.SnowflakeService'>
# 	instrumenting retrieve_context
# 	instrumenting generate_answer
# skipping base <class 'object'> because of class
# skipping base <class 'trulens.providers.cortex.provider.Cortex'> because of class
# skipping base <class 'trulens.feedback.llm_provider.LLMProvider'> because of class
# skipping base <class 'trulens.core.feedback.provider.Provider'> because of class
# skipping base <class 'trulens.core.utils.pyschema.WithClassInfo'> because of class
# skipping base <class 'trulens.core.utils.serial.SerialModel'> because of class
# skipping base <class 'pydantic.main.BaseModel'> because of class
# skipping base <class 'object'> because of class
# skipping base <class 'trulens.core.session.TruSession'> because of class
# skipping base <class 'trulens.core.experimental._WithExperimentalSettings'> because of class
# skipping base <class 'pydantic.main.BaseModel'> because of class
# skipping base <class 'trulens.core.utils.text.WithIdentString'> because of class
# skipping base <class 'trulens.core.utils.python.PydanticSingleton'> because of class
# skipping base <class 'object'> because of class
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/sqlalchemy/engine/default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# OperationalError: no such table: trulens_apps
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[40], line 2
#       1 # Initialize Snowflake service
# ----> 2 service = SnowflakeService(connection_params)
#       3 print("Service initialized successfully!")
#
# File ~/Documents/snowflake-hackathon/frontent_new/snowflake_service.py:58, in __init__(self, connection_params)
#      52     self.tru_provider = Cortex(
#      53         snowpark_session=self.session,
#      54         model_engine="mistral-large"  # Or your desired model
#      55     )
#      56     self.tru_session = TruSession()
# ---> 58     # Initialize RAG app with TruLens monitoring
#      59     self._setup_rag_app()
#      61 def _setup_rag_app(self):
#
# File ~/Documents/snowflake-hackathon/frontent_new/snowflake_service.py:85, in _setup_rag_app(self)
#      64 self.f_groundedness = (
#      65     Feedback(self.tru_provider.groundedness_measure_with_cot_reasons,
#      66              name="Groundedness")
#    (...)
#      69     .aggregate(np.mean)
#      70 )
#      72 self.f_context_relevance = (
#      73     Feedback(self.tru_provider.context_relevance_with_cot_reasons,
#      74              name="Context Relevance")
#    (...)
#      77     .aggregate(np.mean)
#      78 )
#      80 self.f_answer_relevance = (
#      81     Feedback(self.tru_provider.relevance_with_cot_reasons,
#      82              name="Answer Relevance")
#      83     .on_input()
#      84     .on_output()
# ---> 85     .aggregate(np.mean)
#      86 )
#      88 # Create a TruCustomApp wrapper
#      89 self.tru_rag_app = TruCustomApp(
#      90     app=self,
#      91     app_name="SnowflakeRAG",
#    (...)
#      96     ]
#      97 )
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/trulens/apps/custom.py:408, in TruCustomApp.__init__(self, app, methods_to_instrument, **kwargs)
#     405     instrument.include_methods[main_name] = lambda o: isinstance(o, cls)
#     407 # This does instrumentation:
# --> 408 super().__init__(**kwargs)
#     410 # Needed to split this part to after the instrumentation so that the
#     411 # getattr below gets the instrumented version of main method.
#     412 if "main_method" in kwargs:
#     413     # Set main_method to the unbound version. Will be passing in app for
#     414     # "self" manually when needed.
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/trulens/core/app.py:472, in App.__init__(self, connector, feedbacks, **kwargs)
#     469 if self.feedback_mode == feedback_schema.FeedbackMode.WITH_APP_THREAD:
#     470     self._start_manage_pending_feedback_results()
# --> 472 self._tru_post_init()
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/trulens/core/app.py:624, in App._tru_post_init(self)
#     618         logger.warning(
#     619             "`connector` is specified but `feedback_mode` is `FeedbackMode.NONE`. "
#     620             "No feedback evaluation and logging will occur."
#     621         )
#     623 if self.connector is not None:
# --> 624     self.connector.add_app(app=self)
#     626     if self.feedback_mode != feedback_schema.FeedbackMode.NONE:
#     627         logger.debug("Inserting feedback function definitions to db.")
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/trulens/core/database/connector/base.py:166, in DBConnector.add_app(self, app)
#     154 def add_app(self, app: app_schema.AppDefinition) -> types_schema.AppID:
#     155     """
#     156     Add an app to the database and return its unique id.
#     157
#    (...)
#     163
#     164     """
# --> 166     return self.db.insert_app(app=app)
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/trulens/core/database/sqlalchemy.py:474, in SQLAlchemyDB.insert_app(self, app)
#     468 # TODO: thread safety
#     470 with self.session.begin() as session:
#     471     if (
#     472         _app := session.query(self.orm.AppDefinition)
#     473         .filter_by(app_id=app.app_id)
# --> 474         .first()
#     475     ):
#     476         _app.app_json = app.model_dump_json()
#     477     else:
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/sqlalchemy/orm/query.py:2754, in Query.first(self)
#    2752     return self._iter().first()  # type: ignore
#    2753 else:
# -> 2754     return self.limit(1)._iter().first()
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/sqlalchemy/orm/query.py:2853, in Query._iter(self)
#    2850 params = self._params
#    2852 statement = self._statement_20()
# -> 2853 result: Union[ScalarResult[_T], Result[_T]] = self.session.execute(
#    2854     statement,
#    2855     params,
#    2856     execution_options={"_sa_orm_load_options": self.load_options},
#    2857 )
#    2859 # legacy: automatically set scalars, unique
#    2860 if result._attributes.get("is_single_entity", False):
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/sqlalchemy/orm/session.py:2365, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2305 def execute(
#    2306     self,
#    2307     statement: Executable,
#    (...)
#    2313     _add_event: Optional[Any] = None,
#    2314 ) -> Result[Any]:
#    2315     r"""Execute a SQL expression construct.
#    2316
#    2317     Returns a :class:`_engine.Result` object representing
#    (...)
#    2363
#    2364     """
# -> 2365     return self._execute_internal(
#    2366         statement,
#    2367         params,
#    2368         execution_options=execution_options,
#    2369         bind_arguments=bind_arguments,
#    2370         _parent_execute_state=_parent_execute_state,
#    2371         _add_event=_add_event,
#    2372     )
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/sqlalchemy/orm/session.py:2251, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2246     return conn.scalar(
#    2247         statement, params or {}, execution_options=execution_options
#    2248     )
#    2250 if compile_state_cls:
# -> 2251     result: Result[Any] = compile_state_cls.orm_execute_statement(
#    2252         self,
#    2253         statement,
#    2254         params or {},
#    2255         execution_options,
#    2256         bind_arguments,
#    2257         conn,
#    2258     )
#    2259 else:
#    2260     result = conn.execute(
#    2261         statement, params or {}, execution_options=execution_options
#    2262     )
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/sqlalchemy/orm/context.py:305, in AbstractORMCompileState.orm_execute_statement(cls, session, statement, params, execution_options, bind_arguments, conn)
#     295 @classmethod
#     296 def orm_execute_statement(
#     297     cls,
#    (...)
#     303     conn,
#     304 ) -> Result:
# --> 305     result = conn.execute(
#     306         statement, params or {}, execution_options=execution_options
#     307     )
#     308     return cls.orm_setup_cursor_result(
#     309         session,
#     310         statement,
#    (...)
#     314         result,
#     315     )
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/sqlalchemy/sql/elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1638, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1626 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1627     "compiled_cache", self.engine._compiled_cache
#    1628 )
#    1630 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1631     dialect=dialect,
#    1632     compiled_cache=compiled_cache,
#    (...)
#    1636     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1637 )
# -> 1638 ret = self._execute_context(
#    1639     dialect,
#    1640     dialect.execution_ctx_cls._init_compiled,
#    1641     compiled_sql,
#    1642     distilled_parameters,
#    1643     execution_options,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     elem,
#    1647     extracted_params,
#    1648     cache_hit=cache_hit,
#    1649 )
#    1650 if has_events:
#    1651     self.dispatch.after_execute(
#    1652         self,
#    1653         elem,
#    (...)
#    1657         ret,
#    1658     )
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1843, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841     return self._exec_insertmany_context(dialect, context)
#    1842 else:
# -> 1843     return self._exec_single_context(
#    1844         dialect, context, statement, parameters
#    1845     )
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1980     result = context._setup_result_proxy()
#    1982 except BaseException as e:
# -> 1983     self._handle_dbapi_exception(
#    1984         e, str_statement, effective_parameters, cursor, context
#    1985     )
#    1987 return result
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2352, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2350 elif should_wrap:
#    2351     assert sqlalchemy_exception is not None
# -> 2352     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2353 else:
#    2354     assert exc_info[1] is not None
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962                 break
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#    1969     self.dispatch.after_cursor_execute(
#    1970         self,
#    1971         cursor,
#    (...)
#    1975         context.executemany,
#    1976     )
#
# File /opt/anaconda3/envs/getting_started_llmops/lib/python3.11/site-packages/sqlalchemy/engine/default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# OperationalError: (sqlite3.OperationalError) no such table: trulens_apps
# [SQL: SELECT trulens_apps.app_id AS trulens_apps_app_id, trulens_apps.app_name AS trulens_apps_app_name, trulens_apps.app_version AS trulens_apps_app_version, trulens_apps.app_json AS trulens_apps_app_json
# FROM trulens_apps
# WHERE trulens_apps.app_id = ?
#  LIMIT ? OFFSET ?]
# [parameters: ('app_hash_2fd14560bf7d87e7add5ab30495d3eec', 1, 0)]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ## Test File Upload and Processing

# %%
# Create a sample markdown file
test_content = """# Sample Document

This is a test document to verify our RAG implementation.

## Section 1
The capital of France is Paris. It is known as the City of Light.
Paris has many famous landmarks including the Eiffel Tower and the Louvre Museum.

## Section 2
Python is a popular programming language created by Guido van Rossum.
It is known for its simplicity and readability.

## Section 3
Machine learning is a subset of artificial intelligence.
It allows computers to learn from data without being explicitly programmed.
"""

# Create temporary file
with tempfile.NamedTemporaryFile(suffix='.md', delete=False, mode='w') as f:
    f.write(test_content)
    test_file_path = f.name

print(f"Created test file at: {test_file_path}")

# Upload file
with open(test_file_path, 'rb') as f:
    success = service.upload_file(
        file_path=test_file_path,
        file_content=f.read(),
        file_type="MD"
    )

print(f"File upload {'successful' if success else 'failed'}")
# Out:
# Created test file at: /var/folders/_z/ms9rqjt90dq1s5797l_x0ry40000gn/T/tmpgugp2720.md
# File upload successful

# %%
# Debug command 1 - List files
list_stmt = f"LIST @{service.db_name}.{service.schema_name}.document_stage"
staged_files = service.session.sql(list_stmt).collect()
print("Raw staged files:")
for file in staged_files:
    print(file.asDict())

# Debug command 2 - Try parsing one file
if staged_files:
    file_dict = staged_files[0].asDict()
    print("\nFirst file info:", file_dict)
    staged_path = file_dict.get('name', '')
    clean_path = staged_path.replace('document_stage/', '') if staged_path.startswith('document_stage/') else staged_path
    clean_path = clean_path[:-3] if clean_path.endswith('.gz') else clean_path
    print(f"\nStaged path: {staged_path}")
    print(f"Clean path: {clean_path}")
# Out:
# Raw staged files:
# {'name': 'document_stage/FILE_NAME.md', 'size': 31622, 'md5': 'fd38bb5bffb6b0c00980fd8f96cb0689', 'last_modified': 'Sat, 1 Feb 2025 21:48:46 GMT'}
#
# First file info: {'name': 'document_stage/FILE_NAME.md', 'size': 31622, 'md5': 'fd38bb5bffb6b0c00980fd8f96cb0689', 'last_modified': 'Sat, 1 Feb 2025 21:48:46 GMT'}
#
# Staged path: document_stage/FILE_NAME.md
# Clean path: FILE_NAME.md

# %%
# Debug command 3 - Try just the PARSE_DOCUMENT step for one file
if staged_files:
    file_dict = staged_files[0].asDict()
    clean_path = file_dict['name'].replace('document_stage/', '').replace('.gz', '')
    
    parse_stmt = f"""
    SELECT SNOWFLAKE.CORTEX.PARSE_DOCUMENT(
        @{service.db_name}.{service.schema_name}.document_stage,
        '{clean_path}',
        {{'mode': 'LAYOUT'}}
    );
    """
    print("Parse statement:")
    print(parse_stmt)
    try:
        result = service.session.sql(parse_stmt).collect()
        print("\nParse result:", result)
    except Exception as e:
        print("\nParse error:", str(e))
# Out:
# Parse statement:
#
#     SELECT SNOWFLAKE.CORTEX.PARSE_DOCUMENT(
#         @RAG_CHAT_DB.RAG_CHAT_SCHEMA.document_stage,
#         'tmp_c49wlyt.md',
#         {'mode': 'LAYOUT'}
#     );
#
#
# Parse result: [Row(SNOWFLAKE.CORTEX.PARSE_DOCUMENT(
#         @RAG_CHAT_DB.RAG_CHAT_SCHEMA.DOCUMENT_STAGE,
#         'TMP_C49WLYT.MD',
#         {'MODE': 'LAYOUT'}
#     )='{\n  "errorInformation": "The provided file format .txt isn\'t supported. Supported formats: [\'.docx\', \'.pptx\', \'.pdf\']"\n}')]

# %%
# Verify table exists and structure
show_table = f"DESC TABLE {service.db_name}.{service.schema_name}.DOCUMENT_CHUNKS"
try:
    result = service.session.sql(show_table).collect()
    print("Table structure:")
    for row in result:
        print(row.asDict())
except Exception as e:
    print("Table error:", str(e))
# Out:
# Table structure:
# {'name': 'RELATIVE_PATH', 'type': 'VARCHAR(512)', 'kind': 'COLUMN', 'null?': 'Y', 'default': None, 'primary key': 'N', 'unique key': 'N', 'check': None, 'expression': None, 'comment': None, 'policy name': None, 'privacy domain': None}
# {'name': 'FILE_NAME', 'type': 'VARCHAR(256)', 'kind': 'COLUMN', 'null?': 'Y', 'default': None, 'primary key': 'N', 'unique key': 'N', 'check': None, 'expression': None, 'comment': None, 'policy name': None, 'privacy domain': None}
# {'name': 'CHUNK_ID', 'type': 'NUMBER(38,0)', 'kind': 'COLUMN', 'null?': 'Y', 'default': 'IDENTITY START 1 INCREMENT 1 NOORDER', 'primary key': 'N', 'unique key': 'N', 'check': None, 'expression': None, 'comment': None, 'policy name': None, 'privacy domain': None}
# {'name': 'CHUNK_TEXT', 'type': 'VARCHAR(16777216)', 'kind': 'COLUMN', 'null?': 'Y', 'default': None, 'primary key': 'N', 'unique key': 'N', 'check': None, 'expression': None, 'comment': None, 'policy name': None, 'privacy domain': None}
# {'name': 'CREATED_AT', 'type': 'TIMESTAMP_NTZ(9)', 'kind': 'COLUMN', 'null?': 'Y', 'default': 'CURRENT_TIMESTAMP()', 'primary key': 'N', 'unique key': 'N', 'check': None, 'expression': None, 'comment': None, 'policy name': None, 'privacy domain': None}
# {'name': 'FILE_TYPE', 'type': 'VARCHAR(10)', 'kind': 'COLUMN', 'null?': 'Y', 'default': None, 'primary key': 'N', 'unique key': 'N', 'check': None, 'expression': None, 'comment': None, 'policy name': None, 'privacy domain': None}
# {'name': 'FILE_SIZE', 'type': 'NUMBER(38,0)', 'kind': 'COLUMN', 'null?': 'Y', 'default': None, 'primary key': 'N', 'unique key': 'N', 'check': None, 'expression': None, 'comment': None, 'policy name': None, 'privacy domain': None}
# {'name': 'METADATA', 'type': 'VARIANT', 'kind': 'COLUMN', 'null?': 'Y', 'default': None, 'primary key': 'N', 'unique key': 'N', 'check': None, 'expression': None, 'comment': None, 'policy name': None, 'privacy domain': None}

# %%
# Process staged files
processed_files = service.process_staged_files()
print(f"Processed files: {processed_files}")
# Out:
# Found 1 files in stage
# Sample file info: {'name': 'document_stage/FILE_NAME.md', 'size': 31622, 'md5': 'fd38bb5bffb6b0c00980fd8f96cb0689', 'last_modified': 'Sat, 1 Feb 2025 21:48:46 GMT'}
# Processing file: FILE_NAME.md (Path: FILE_NAME.md)
# File extension: .md
# Result when getting markdown: [Row($1='# TickTick MCP Server Implementation Plan'), Row($1=None), Row($1='## Overview'), Row($1="An MCP server implementation that integrates TickTick's task management capabilities with LLM-powered planning and organization features. The server will enable LLMs like Claude to interact with TickTick for creating and managing tasks"), Row($1=None), Row($1='## Core Features'), Row($1=None), Row($1='### 1. Authentication & Setup'), Row($1='- **OAuth2 Integration**'), Row($1='  - Implementation: Complex'), Row($1='  - Priority: High'), Row($1='  - Components:'), Row($1='    - OAuth2 flow implementation'), Row($1='    - Token management and refresh'), Row($1='    - Secure credential storage'), Row($1='  - Technical Considerations:'), Row($1='    - Environment variables for client credentials'), Row($1='    - Secure token storage'), Row($1='    - Token refresh handling'), Row($1=None), Row($1='### 2. Task Management'), Row($1='- **Task Operations**'), Row($1='  - Implementation: Medium'), Row($1='  - Priority: High'), Row($1='  - Features:'), Row($1='    - Create new tasks'), Row($1='    - Update existing tasks'), Row($1='    - Delete tasks'), Row($1='    - Complete/uncomplete tasks'), Row($1='    - Set task priorities'), Row($1='    - Add due dates and reminders'), Row($1='    - Handle recurring tasks'), Row($1='  - Technical Considerations:'), Row($1='    - Task validation'), Row($1='    - Error handling'), Row($1='    - Date/time handling across timezones'), Row($1=None), Row($1='### 3. Project Management'), Row($1='- **Project Operations**'), Row($1='  - Implementation: Medium'), Row($1='  - Priority: High'), Row($1='  - Features:'), Row($1='    - Create projects'), Row($1='    - Update project details'), Row($1='    - Delete projects'), Row($1='    - Organize tasks within projects'), Row($1='    - Handle project hierarchies'), Row($1='  - Technical Considerations:'), Row($1='    - Project structure validation'), Row($1='    - Permission handling'), Row($1='    - Project-task relationships'), Row($1=None), Row($1='### 4. Time Management'), Row($1='- **Time Blocking Features**'), Row($1='  - Implementation: Complex'), Row($1='  - Priority: Medium'), Row($1='  - Features:'), Row($1='    - Create time blocks'), Row($1='    - Schedule tasks'), Row($1='    - Handle conflicts'), Row($1='    - Manage calendar integration'), Row($1='  - Technical Considerations:'), Row($1='    - Calendar sync'), Row($1='    - Time slot availability'), Row($1='    - Conflict resolution'), Row($1=None), Row($1='### 5. Checklist Management'), Row($1='- **Checklist Operations**'), Row($1='  - Implementation: Simple'), Row($1='  - Priority: Medium'), Row($1='  - Features:'), Row($1='    - Create checklists'), Row($1='    - Add/remove items'), Row($1='    - Track completion'), Row($1='    - Convert checklists to tasks'), Row($1='  - Technical Considerations:'), Row($1='    - Checklist item validation'), Row($1='    - Progress tracking'), Row($1='    - Task conversion logic'), Row($1=None), Row($1='## MCP Implementation'), Row($1=None), Row($1='### Resources'), Row($1='1. **Project Resources**'), Row($1='   ```'), Row($1='   projects://list'), Row($1='   projects://{projectId}'), Row($1='   projects://{projectId}/tasks'), Row($1='   ```'), Row($1=None), Row($1='2. **Task Resources**'), Row($1='   ```'), Row($1='   tasks://list'), Row($1='   tasks://{taskId}'), Row($1='   tasks://due-today'), Row($1='   tasks://overdue'), Row($1='   ```'), Row($1=None), Row($1='3. **Time Block Resources**'), Row($1='   ```'), Row($1='   timeblocks://today'), Row($1='   timeblocks://{date}'), Row($1='   timeblocks://week'), Row($1='   ```'), Row($1=None), Row($1='### Tools'), Row($1='1. **Task Tools**'), Row($1='   - `create-task`'), Row($1='   - `update-task`'), Row($1='   - `delete-task`'), Row($1='   - `complete-task`'), Row($1='   - `move-task`'), Row($1=None), Row($1='2. **Project Tools**'), Row($1='   - `create-project`'), Row($1='   - `upda ...
# Full document length: 29976
# Content length: 29976
# # TickTick MCP Server Implementation Plan
#
# ## Overview
# An MCP server implementation that integrates TickTick's task management capabilities with LLM-powered planning and organization features. The server will enable LLMs like Claude to interact with TickTick for creating and managing tasks
#
# ## Core Features
#
# ### 1. Authentication & Setup
# - **OAuth2 Integration**
#   - Implementation: Complex
#   - Priority: High
#   - Components:
#     - OAuth2 flow implementation
#     - Token management and refresh
#     - Secure credential storage
#   - Technical Considerations:
#     - Environment variables for client credentials
#     - Secure token storage
#     - Token refresh handling
#
# ### 2. Task Management
# - **Task Operations**
#   - Implementation: Medium
#   - Priority: High
#   - Features:
#     - Create new tasks
#     - Update existing tasks
#     - Delete tasks
#     - Complete/uncomplete tasks
#     - Set task priorities
#     - Add due dates and reminders
#     - Handle recurring tasks
#   - Technical Considerations:
#     - Task validation
#     - Error handling
#     - Date/time handling across timezones
#
# ### 3. Project Management
# - **Project Operations**
#   - Implementation: Medium
#   - Priority: High
#   - Features:
#     - Create projects
#     - Update project details
#     - Delete projects
#     - Organize tasks within projects
#     - Handle project hierarchies
#   - Technical Considerations:
#     - Project structure validation
#     - Permission handling
#     - Project-task relationships
#
# ### 4. Time Management
# - **Time Blocking Features**
#   - Implementation: Complex
#   - Priority: Medium
#   - Features:
#     - Create time blocks
#     - Schedule tasks
#     - Handle conflicts
#     - Manage calendar integration
#   - Technical Considerations:
#     - Calendar sync
#     - Time slot availability
#     - Conflict resolution
#
# ### 5. Checklist Management
# - **Checklist Operations**
#   - Implementation: Simple
#   - Priority: Medium
#   - Features:
#     - Create checklists
#     - Add/remove items
#     - Track completion
#     - Convert checklists to tasks
#   - Technical Considerations:
#     - Checklist item validation
#     - Progress tracking
#     - Task conversion logic
#
# ## MCP Implementation
#
# ### Resources
# 1. **Project Resources**
#    ```
#    projects://list
#    projects://{projectId}
#    projects://{projectId}/tasks
#    ```
#
# 2. **Task Resources**
#    ```
#    tasks://list
#    tasks://{taskId}
#    tasks://due-today
#    tasks://overdue
#    ```
#
# 3. **Time Block Resources**
#    ```
#    timeblocks://today
#    timeblocks://{date}
#    timeblocks://week
#    ```
#
# ### Tools
# 1. **Task Tools**
#    - `create-task`
#    - `update-task`
#    - `delete-task`
#    - `complete-task`
#    - `move-task`
#
# 2. **Project Tools**
#    - `create-project`
#    - `update-project`
#    - `delete-project`
#    - `organize-tasks`
#
# 3. **Time Management Tools**
#    - `create-time-block`
#    - `schedule-task`
#    - `optimize-schedule`
#    - `resolve-conflicts`
#
# 4. **Checklist Tools**
#    - `create-checklist`
#    - `update-checklist`
#    - `convert-to-tasks`
#
# ### Prompts
# 1. **Task Creation Prompts**
#    - Project task creation
#    - Quick task addition
#    - Recurring task setup
#
# 2. **Planning Prompts**
#    - Time blocking assistance
#    - Project planning
#    - Schedule optimization
#
# 3. **Analysis Prompts**
#    - Time usage analysis
#    - Project progress review
#    - Task organization suggestions
#
# ## Technical Architecture
#
# ### Components
# 1. **Auth Manager**
#    - OAuth2 flow handling
#    - Token management
#    - Session handling
#
# 2. **TickTick API Client**
#    - API request handling
#    - Rate limiting
#    - Error handling
#    - Response parsing
#
# 3. **Resource Manager**
#    - Resource caching
#    - Update notifications
#    - Data formatting
#
# 4. **Tool Manager**
#    - Tool execution
#    - Input validation
#    - Error handling
#    - Progress tracking
#
# ### Data Models
# 1. **Task Model**
#    ```typescript
#    interface Task {
#      id: string;
#      title: string;
#      description?: string;
#      due_date?: string;
#      priority: number;
#      status: string;
#      project_id?: string;
#      checklist?: ChecklistItem[];
#      time_block?: TimeBlock;
#    }
#    ```
#
# 2. **Project Model**
#    ```typescript
#    interface Project {
#      id: string;
#      name: string;
#      description?: string;
#      color?: string;
#      tasks: Task[];
#      status: string;
#    }
#    ```
#
# 3. **TimeBlock Model**
#    ```typescript
#    interface TimeBlock {
#      id: string;
#      start_time: string;
#      end_time: string;
#      task_id?: string;
#      description?: string;
#    }
#    ```
#
# ## Implementation Phases
#
# ### Phase 1: Core Setup
# - OAuth2 implementation
# - Basic task CRUD operations
# - Project management
# - Test infrastructure
#
# ### Phase 2: Advanced Features
# - Time blocking
# - Checklist management
# - Calendar integration
# - Resource caching
#
# ### Phase 3: LLM Integration
# - Prompt engineering
# - Tool optimization
# - Context management
# - Documentation
#
# ## Technical Considerations
#
# ### Security
# - OAuth2 token security
# - Input validation
# - Rate limiting
# - Error handling
#
# ### Performance
# - Resource caching
# - Batch operations
# - Connection pooling
# - Response optimization
#
# ### Reliability
# - Error recovery
# - Token refresh
# - Data validation
# - Conflict resolution
#
# ## LLM Integration Design
#
# ### Context Management
# - Project structure exposure
# - Task relationship mapping
# - Time block visualization
# - Progress tracking
#
# ### Tool Design
# - Clear parameter schemas
# - Comprehensive descriptions
# - Error feedback
# - Progress reporting
#
# ### Prompt Engineering
# - Task creation templates
# - Planning assistance
# - Time management
# - Project organization
#
# ## Development Requirements
#
# ### Dependencies
# - MCP SDK
# - HTTP client
# - OAuth2 library
# - Date/time handling
# - JSON processing
#
# ### Development Tools
# - TypeScript/Python
# - Testing framework
# - Documentation generator
# - Code linting
# - Version control
#
# ## Future Enhancements
#
# ### Potential Features
# - Natural language time parsing
# - Smart task categorization
# - Productivity analytics
# - Multi-user support
# - Template management
#
# ### Integration Opportunities
# - Calendar services
# - Note-taking apps
# - Email integration
# - Mobile notifications
#
# ## Success Metrics
#
# ### Performance Metrics
# - API response time
# - Tool execution speed
# - Resource update time
# - Error rate
#
# ### User Experience Metrics
# - Task completion rate
# - Planning efficiency
# - Time block utilization
# - Error recovery rate
#
# ## Risks and Mitigation
#
# ### Technical Risks
# 1. API Rate Limiting
#    - Implement caching
#    - Batch operations
#    - Request queuing
#
# 2. OAuth2 Complexity
#    - Clear documentation
#    - Error handling
#    - Token management
#
# 3. Data Synchronization
#    - Conflict resolution
#    - Version tracking
#    - Change notification
#
# ### Mitigation Strategies
# 1. Comprehensive testing
# 2. Gradual feature rollout
# 3. Monitoring and logging
# 4. User feedback collection
# 5. Performance optimization
#
# ## User FAQs
#
# ### Q: Will additional persistent storage be needed?
# **Confidence: 9/10**
#
# Yes
# 1. OAuth token storage and management
# 2. User preferences and settings
# 3. Local caching of task/project data for performance
# 4. Mapping between TickTick IDs and local references
# 5. Storage of custom timeblock metadata not supported by TickTick
#
# SQLite is chosen because:
# - Lightweight and serverless
# - Built-in support in Python/Node.js
# - Perfect for local data persistence
# - Easy backup and maintenance
# - No separate server needed
#
# ### Q: What do Resources do in this context?
# **Confidence: 10/10**
#
# Resources in MCP are read-only data endpoints that expose current state:
#
# 1. **Project Resources** (`projects://...`)
#    - Provide current project structure
#    - List available projects
#    - Show project details and metadata
#    - Expose task organization within projects
#
# 2. **Task Resources** (`tasks://...`)
#    - Expose current task lists
#    - Show task details and status
#    - Provide filtered views (due today
#    - Display task relationships and dependencies
#
# 3. **Time Block Resources** (`timeblocks://...`)
#    - Show scheduled time blocks
#    - Expose calendar view of tasks
#    - Provide daily/weekly schedule views
#    - Display available time slots
#
# Resources are used by LLMs to understand the current state before making changes through Tools.
#
# ### Q: Will calendar access be needed?
# **Confidence: 7/10**
#
# Direct calendar integration isn't immediately necessary as TickTick provides:
# - Start/due dates for tasks
# - All-day task flags
# - Time zone handling
# - Basic scheduling features
#
# However
# - Google Calendar integration
# - iCal feed support
# - External calendar sync
# - Multi-calendar view
#
# ### Q: How does TickTick's API support timeblocking?
# **Confidence: 8/10**
#
# TickTick's API doesn't directly support timeblocking
#
# 1. Task Properties We Can Use:
#    - `startDate`: Block start time
#    - `dueDate`: Block end time
#    - `isAllDay`: Full-day blocks
#    - `timeZone`: Time zone handling
#    - `priority`: Block importance
#    - `status`: Block completion
#
# 2. Implementation Approach:
#    - Create tasks with specific start/end times
#    - Use task description for block metadata
#    - Leverage priority for block importance
#    - Use projects for block categorization
#
# 3. Additional Metadata:
#    - Store extra timeblock data in local SQLite
#    - Map tasks to timeblock properties
#    - Handle block conflicts locally
#    - Manage block relationships
#
# 4. Limitations:
#    - No native block duration
#    - No direct block visualization
#    - Manual conflict handling needed
#    - Custom UI needed for block view
#
# ### Q: How are MCP resources updated and who manages them?
# **Confidence: 9/10**
#
# Resource updates in MCP follow a specific pattern:
#
# 1. **Update Mechanisms:**
#    - Server-side polling of TickTick API
#    - Webhook support for real-time updates (if TickTick provides them)
#    - Local cache refresh mechanisms
#    - Client subscription notifications
#
# 2. **Update Responsibility:**
#    - The MCP server is responsible for keeping resources up-to-date
#    - Updates happen through:
#      - Regular polling of TickTick API
#      - Response to client subscription requests
#      - After successful tool executions
#      - Background refresh jobs
#
# 3. **Client Notification:**
#    - Clients can subscribe to resource changes
#    - Server sends notifications when resources update
#    - Supported through MCP's `resources.subscribe` capability
#    - Immediate notification of state changes
#
# 4. **Synchronization Flow:**
#    ```
#    TickTick API -> MCP Server -> Resource Cache -> Client Notifications
#    ```
#
# ### Q: What analytics capabilities can be implemented?
# **Confidence: 8/10**
#
# We can implement various analytics features by combining TickTick data with local tracking:
#
# 1. **Task Analytics:**
#    - Completion rates by project/timeframe
#    - Average task duration
#    - Priority distribution
#    - Due date adherence
#    - Task complexity patterns
#
# 2. **Time Analytics:**
#    - Time spent per project
#    - Productive hours analysis
#    - Time block utilization
#    - Schedule adherence rates
#    - Peak productivity periods
#
# 3. **Project Analytics:**
#    - Project completion rates
#    - Timeline adherence
#    - Resource utilization
#    - Milestone achievement
#    - Bottleneck identification
#
# 4. **Performance Metrics:**
#    - Personal productivity scores
#    - Time estimation accuracy
#    - Goal achievement rates
#    - Work pattern analysis
#    - Focus session tracking
#
# 5. **Custom Analytics:**
#    - Through local SQLite tracking:
#      - Custom productivity metrics
#      - Time block effectiveness
#      - Work-break patterns
#      - Energy level correlation
#      - Context switching frequency
#
# 6. **Visualization Options:**
#    - Time distribution charts
#    - Project progress graphs
#    - Productivity heatmaps
#    - Task completion trends
#    - Schedule optimization suggestions
#
# ### Q: Does TickTick support webhooks for real-time updates?
# **Confidence: 10/10**
#
# No
#
# 1. **Available Update Methods:**
#    - Regular API polling
#    - Response-based updates
#    - Client-initiated refresh
#
# 2. **Update Strategy:**
#    - Implement smart polling with configurable intervals
#    - Cache responses to minimize API calls
#    - Update on tool execution completion
#    - Provide manual refresh capabilities
#
# ### Q: Can the server be designed for task management app portability?
# **Confidence: 9/10**
#
# Yes
#
# 1. **Architecture Layers:**
#    ```
#    MCP Server
#       ↓
#    Task Management Interface (Abstract)
#       ↓
#    Provider Implementations
#       ├── TickTick Provider
#       ├── Future Provider 1
#       └── Future Provider 2
#    ```
#
# 2. **Core Abstractions:**
#    ```typescript
#    interface TaskProvider {
#      getTasks(): Promise<Task[]>;
#      createTask(task: TaskInput): Promise<Task>;
#      updateTask(id: string
#      deleteTask(id: string): Promise<void>;
#      // ... other task operations
#    }
#
#    interface ProjectProvider {
#      getProjects(): Promise<Project[]>;
#      createProject(project: ProjectInput): Promise<Project>;
#      // ... project operations
#    }
#
#    interface TimeBlockProvider {
#      getTimeBlocks(date: Date): Promise<TimeBlock[]>;
#      createTimeBlock(block: TimeBlockInput): Promise<TimeBlock>;
#      // ... time block operations
#    }
#    ```
#
# 3. **Benefits:**
#    - Easy provider swapping
#    - Consistent interface
#    - Shared utilities
#    - Provider-specific optimizations
#    - Unified error handling
#
# 4. **Implementation Strategy:**
#    - Start with TickTick implementation
#    - Abstract common patterns
#    - Document interface requirements
#    - Create provider template
#    - Build test suite for providers
#
# ### Q: Can this MCP server be used with frontend frameworks?
# **Confidence: 8/10**
#
# Yes
#
# 1. **Integration Options:**
#
#    a. **Server-Sent Events (SSE):**
#    ```typescript
#    // NextJS Example
#    const EventSource = require('eventsource');
#
#    function TaskManager() {
#      useEffect(() => {
#        const sse = new EventSource('/api/mcp/sse');
#        sse.onmessage = (event) => {
#          // Handle updates
#        };
#        return () => sse.close();
#      }
#    }
#    ```
#
#    b. **HTTP Transport:**
#    ```typescript
#    // API Route Example
#    async function handler(req
#      const response = await fetch('http://localhost:3000/mcp'
#        method: 'POST'
#        body: JSON.stringify(req.body)
#      });
#      return res.json(await response.json());
#    }
#    ```
#
# 2. **Framework Support:**
#    - Next.js: Full support via API routes and SSE
#    - Streamlit: Direct integration through Python
#    - React: Through proxy setup
#    - Vue: Through proxy setup
#    - Angular: Through proxy setup
#
# 3. **Integration Methods:**
#    - Direct API calls
#    - WebSocket connections (if implemented)
#    - Server-Sent Events
#    - HTTP long polling
#
# 4. **Security Considerations:**
#    - CORS configuration
#    - Authentication handling
#    - Rate limiting
#    - Error handling
#
# ## Implementation Strategy
#
# ### Stage 1: Foundation & Basic Task Management
# **Objective:** Set up core infrastructure and basic task operations
#
# 1. **Project Setup [2-3 days]**
#    - [ ] Basic MCP server structure
#    - [ ] Development environment configuration
#    - [ ] Testing framework setup
#    - [ ] CI/CD pipeline (basic)
#
#    **Deliverables:**
#    - Working server skeleton
#    - README with setup instructions
#    - Basic test suite
#
#    **Handoff Checklist:**
#    - [ ] Server starts and responds to basic requests
#    - [ ] All tests passing
#    - [ ] Development environment documented
#    - [ ] Basic error handling implemented
#
# 2. **Authentication Layer [3-4 days]**
#    - [ ] OAuth2 implementation
#    - [ ] Token management
#    - [ ] Local storage setup
#    - [ ] Error handling
#
#    **Deliverables:**
#    - Working OAuth flow
#    - Token persistence
#    - Basic user session management
#
#    **Handoff Checklist:**
#    - [ ] OAuth flow works end-to-end
#    - [ ] Tokens persist across restarts
#    - [ ] Error handling for auth failures
#    - [ ] Token refresh works
#    - [ ] Security tests passing
#
# 3. **Basic Task Operations [4-5 days]**
#    - [ ] Task provider interface
#    - [ ] TickTick implementation
#    - [ ] Basic CRUD operations
#    - [ ] Task resource endpoints
#
#    **Deliverables:**
#    - Working task management
#    - Basic CLI for testing
#    - Task CRUD tests
#
#    **Handoff Checklist:**
#    - [ ] Can create/read/update/delete tasks
#    - [ ] Task operations properly error handled
#    - [ ] Resource endpoints working
#    - [ ] Integration tests passing
#    - [ ] Works with Claude Desktop
#
# ### Stage 2: Project Management & Enhanced Tasks
# **Objective:** Add project support and enhance task capabilities
#
# 1. **Project Management [3-4 days]**
#    - [ ] Project provider interface
#    - [ ] Basic project operations
#    - [ ] Project-task relationships
#    - [ ] Project resources
#
#    **Deliverables:**
#    - Project CRUD operations
#    - Project-task organization
#    - Updated tests
#
#    **Handoff Checklist:**
#    - [ ] Project operations working
#    - [ ] Can organize tasks in projects
#    - [ ] Project resources accessible
#    - [ ] Project tests passing
#    - [ ] Claude can manage projects
#
# 2. **Enhanced Task Features [4-5 days]**
#    - [ ] Due dates and reminders
#    - [ ] Priority management
#    - [ ] Recurring tasks
#    - [ ] Task dependencies
#
#    **Deliverables:**
#    - Enhanced task management
#    - Extended task resources
#    - Updated documentation
#
#    **Handoff Checklist:**
#    - [ ] All task features implemented
#    - [ ] Resource updates working
#    - [ ] Feature tests passing
#    - [ ] Claude can use all features
#    - [ ] Documentation updated
#
# ### Stage 3: Time Management & Scheduling
# **Objective:** Implement time management features
#
# 1. **Basic Time Blocking [4-5 days]**
#    - [ ] Time block interface
#    - [ ] Basic scheduling
#    - [ ] Time block resources
#    - [ ] Block visualization data
#
#    **Deliverables:**
#    - Basic time blocking
#    - Schedule visualization data
#    - Time management tests
#
#    **Handoff Checklist:**
#    - [ ] Can create time blocks
#    - [ ] Basic scheduling works
#    - [ ] Resource endpoints working
#    - [ ] Tests passing
#    - [ ] Claude can create schedules
#
# 2. **Advanced Scheduling [5-6 days]**
#    - [ ] Conflict detection
#    - [ ] Schedule optimization
#    - [ ] Calendar views
#    - [ ] Time analytics
#
#    **Deliverables:**
#    - Advanced scheduling features
#    - Analytics endpoints
#    - Updated documentation
#
#    **Handoff Checklist:**
#    - [ ] Conflict handling works
#    - [ ] Schedule optimization working
#    - [ ] Analytics accessible
#    - [ ] All tests passing
#    - [ ] Claude can optimize schedules
#
# ### Stage 4: Analytics & Optimization
# **Objective:** Add analytics and optimization features
#
# 1. **Basic Analytics [4-5 days]**
#    - [ ] Task completion tracking
#    - [ ] Time usage analysis
#    - [ ] Basic reporting
#    - [ ] Analytics resources
#
#    **Deliverables:**
#    - Basic analytics features
#    - Analytics resources
#    - Testing tools
#
#    **Handoff Checklist:**
#    - [ ] Analytics collection working
#    - [ ] Basic reports available
#    - [ ] Resource endpoints working
#    - [ ] Tests passing
#    - [ ] Claude can generate reports
#
# 2. **Advanced Analytics [5-6 days]**
#    - [ ] Productivity scoring
#    - [ ] Pattern recognition
#    - [ ] Optimization suggestions
#    - [ ] Enhanced reporting
#
#    **Deliverables:**
#    - Advanced analytics
#    - Optimization tools
#    - Documentation updates
#
#    **Handoff Checklist:**
#    - [ ] Advanced analytics working
#    - [ ] Pattern detection operational
#    - [ ] Suggestion system working
#    - [ ] All tests passing
#    - [ ] Claude can provide insights
#
# ### Stage 5: Integration & Polish
# **Objective:** Enhance integration capabilities and polish features
#
# 1. **Frontend Integration [4-5 days]**
#    - [ ] SSE implementation
#    - [ ] Frontend examples
#    - [ ] API documentation
#    - [ ] Integration tests
#
#    **Deliverables:**
#    - Frontend integration support
#    - Example applications
#    - API documentation
#
#    **Handoff Checklist:**
#    - [ ] SSE working properly
#    - [ ] Example apps functional
#    - [ ] Documentation complete
#    - [ ] Integration tests passing
#
# 2. **System Polish [3-4 days]**
#    - [ ] Performance optimization
#    - [ ] Error handling review
#    - [ ] Documentation updates
#    - [ ] Final testing
#
#    **Deliverables:**
#    - Optimized system
#    - Complete documentation
#    - Full test coverage
#
#    **Handoff Checklist:**
#    - [ ] Performance metrics met
#    - [ ] Error handling comprehensive
#    - [ ] Documentation complete
#    - [ ] All tests passing
#    - [ ] System ready for production
#
# ### Testing Requirements
#
# Each stage requires:
# 1. **Unit Tests**
#    - Individual component testing
#    - Error case coverage
#    - Edge case handling
#
# 2. **Integration Tests**
#    - Component interaction testing
#    - End-to-end workflows
#    - Client integration testing
#
# 3. **Performance Tests**
#    - Response time benchmarks
#    - Resource usage monitoring
#    - Concurrency testing
#
# 4. **Security Tests**
#    - Authentication testing
#    - Authorization checks
#    - Data protection verification
#
# ### Documentation Requirements
#
# Each stage requires:
# 1. **API Documentation**
#    - Endpoint specifications
#    - Request/response examples
#    - Error handling details
#
# 2. **User Documentation**
#    - Feature guides
#    - Configuration instructions
#    - Troubleshooting guides
#
# 3. **Development Documentation**
#    - Architecture overview
#    - Setup instructions
#    - Contribution guidelines
#
# ## Project File Structure & Implementation Details
#
# ```
# ticktick-mcp/
# ├── src/
# │   ├── core/                        # Core MCP Server Implementation
# │   │   ├── server.ts               # Main MCP server setup and configuration
# │   │   ├── types.ts                # Core type definitions
# │   │   ├── config.ts               # Configuration management
# │   │   └── constants.ts            # System constants
# │   │
# │   ├── auth/                       # Authentication System
# │   │   ├── oauth.ts                # OAuth2 implementation
# │   │   ├── token.ts                # Token management
# │   │   ├── storage.ts              # Token storage implementation
# │   │   └── types.ts                # Auth-related types
# │   │
# │   ├── providers/                  # Provider Implementations
# │   │   ├── interfaces/             # Provider Interfaces
# │   │   │   ├── task.ts            # Task provider interface
# │   │   │   ├── project.ts         # Project provider interface
# │   │   │   ├── timeblock.ts       # Time block provider interface
# │   │   │   └── analytics.ts       # Analytics provider interface
# │   │   │
# │   │   └── ticktick/              # TickTick Implementation
# │   │       ├── provider.ts         # Main TickTick provider
# │   │       ├── api.ts             # TickTick API client
# │   │       ├── mapper.ts          # Data mapping utilities
# │   │       └── types.ts           # TickTick-specific types
# │   │
# │   ├── models/                     # Data Models
# │   │   ├── task.ts                # Task model and types
# │   │   ├── project.ts             # Project model and types
# │   │   ├── timeblock.ts           # Time block model
# │   │   ├── analytics.ts           # Analytics models
# │   │   └── common.ts              # Shared model types
# │   │
# │   ├── storage/                    # Storage Systems
# │   │   ├── db/                    # Database
# │   │   │   ├── schema.ts          # Database schema
# │   │   │   ├── migrations/        # Schema migrations
# │   │   │   └── queries/           # SQL queries
# │   │   │
# │   │   └── cache/                 # Caching
# │   │       ├── manager.ts         # Cache management
# │   │       ├── strategies.ts      # Cache strategies
# │   │       └── types.ts           # Cache-related types
# │   │
# │   ├── services/                   # Business Logic Services
# │   │   ├── task/                  # Task Services
# │   │   │   ├── manager.ts         # Task management
# │   │   │   ├── recurring.ts       # Recurring tasks
# │   │   │   └── validation.ts      # Task validation
# │   │   │
# │   │   ├── project/               # Project Services
# │   │   │   ├── manager.ts         # Project management
# │   │   │   └── relationships.ts   # Project relationships
# │   │   │
# │   │   ├── timeblock/             # Time Block Services
# │   │   │   ├── manager.ts         # Time block management
# │   │   │   ├── scheduler.ts       # Scheduling logic
# │   │   │   └── conflicts.ts       # Conflict detection
# │   │   │
# │   │   └── analytics/             # Analytics Services
# │   │       ├── collector.ts       # Data collection
# │   │       ├── analyzer.ts        # Data analysis
# │   │       └── reporter.ts        # Report generation
# │   │
# │   ├── optimization/               # Optimization Systems
# │   │   ├── engine.ts              # Optimization engine
# │   │   ├── strategies.ts          # Optimization strategies
# │   │   ├── learning.ts            # Learning system
# │   │   └── types.ts               # Optimization types
# │   │
# │   ├── integration/                # Integration Layer
# │   │   ├── transport/             # Transport Layer
# │   │   │   ├── sse.ts            # SSE implementation
# │   │   │   ├── rest.ts           # REST endpoints
# │   │   │   └── websocket.ts      # WebSocket support
# │   │   │
# │   │   └── sdk/                  # Client SDKs
# │   │       ├── js/               # JavaScript SDK
# │   │       └── react/            # React Components
# │   │
# │   └── utils/                     # Utilities
# │       ├── logger.ts              # Logging utilities
# │       ├── error.ts               # Error handling
# │       ├── validation.ts          # Validation utilities
# │       └── date.ts               # Date/time utilities
# │
# ├── tests/                         # Test Suite
# │   ├── unit/                     # Unit Tests
# │   │   ├── providers/            # Provider tests
# │   │   ├── services/             # Service tests
# │   │   └── utils/                # Utility tests
# │   │
# │   ├── integration/              # Integration Tests
# │   │   ├── api/                 # API tests
# │   │   ├── auth/                # Auth flow tests
# │   │   └── e2e/                 # End-to-end tests
# │   │
# │   └── fixtures/                # Test fixtures
# │
# ├── docs/                         # Documentation
# │   ├── api/                     # API documentation
# │   ├── guides/                  # User guides
# │   └── examples/                # Example code
# │
# └── scripts/                     # Development Scripts
#     ├── setup.ts                 # Setup script
#     ├── build.ts                 # Build script
#     └── deploy.ts                # Deployment script
# ```
#
# ## Component Details
#
# ### Core Components
#
# #### Server (`src/core/server.ts`)
# - MCP server initialization and configuration
# - Protocol handling and message routing
# - Server lifecycle management
# - Capability registration
#
# #### Types (`src/core/types.ts`)
# - Core type definitions
# - Interface declarations
# - Shared type utilities
# - Protocol types
#
# ### Authentication System
#
# #### OAuth (`src/auth/oauth.ts`)
# - OAuth2 flow implementation
# - Authorization handling
# - Token exchange logic
# - Error handling
#
# #### Token Management (`src/auth/token.ts`)
# - Token lifecycle management
# - Refresh token handling
# - Token validation
# - Expiry management
#
# ### Provider Layer
#
# #### Provider Interfaces (`src/providers/interfaces/`)
# - Abstract provider definitions
# - Type declarations
# - Method contracts
# - Error types
#
# #### TickTick Provider (`src/providers/ticktick/`)
# - TickTick API integration
# - Data mapping/transformation
# - Error handling
# - Rate limiting
#
# ### Models
#
# #### Task Model (`src/models/task.ts`)
# - Task data structure
# - Validation rules
# - State management
# - Type definitions
#
# #### Project Model (`src/models/project.ts`)
# - Project structure
# - Relationships
# - Metadata
# - Validation
#
# ### Services
#
# #### Task Services (`src/services/task/`)
# - Task CRUD operations
# - Recurring task handling
# - Validation logic
# - Error handling
#
# #### Time Block Services (`src/services/timeblock/`)
# - Time block management
# - Scheduling algorithms
# - Conflict detection
# - Optimization
#
# ### Storage System
#
# #### Database (`src/storage/db/`)
# - Schema definitions
# - Migration system
# - Query builders
# - Connection management
#
# #### Cache (`src/storage/cache/`)
# - Cache strategies
# - Invalidation logic
# - Performance optimization
# - Distribution
#
# ### Integration Layer
#
# #### Transport (`src/integration/transport/`)
# - Communication protocols
# - Message handling
# - Connection management
# - Error recovery
#
# #### SDKs (`src/integration/sdk/`)
# - Client libraries
# - API wrappers
# - Type definitions
# - Example code
#
# ## Key Implementation Details
#
# ### 1. Authentication Flow
# - Implements complete OAuth2 flow
# - Secure token storage
# - Automatic token refresh
# - Session management
#
# ### 2. Data Synchronization
# - Real-time updates
# - Conflict resolution
# - Cache invalidation
# - Consistency checks
#
# ### 3. Performance Optimization
# - Smart caching
# - Request batching
# - Connection pooling
# - Load balancing
#
# ### 4. Error Handling
# - Comprehensive error types
# - Recovery strategies
# - Logging system
# - User feedback
#
# ### 5. Testing Strategy
# - Unit test coverage
# - Integration testing
# - E2E test suites
# - Performance testing
#
# ## Dependencies
#
# ### Core Dependencies
# - `mcp-sdk`: MCP protocol implementation
# - `sqlite3`: Database engine
# - `date-fns`: Date manipulation
# - `zod`: Schema validation
#
# ### Development Dependencies
# - `typescript`: Type system
# - `jest`: Testing framework
# - `eslint`: Code linting
# - `prettier`: Code formatting
#
# ### Optional Dependencies
# - `redis`: Distributed caching
# - `bull`: Job queue
# - `winston`: Advanced logging
# - `opentelemetry`: Monitoring
#
# ## Getting Started
#
# ### Development Setup
# 1. Install dependencies
# 2. Configure environment
# 3. Initialize database
# 4. Start development server
#
# ### Build Process
# 1. Lint code
# 2. Run tests
# 3. Build TypeScript
# 4. Generate documentation
#
# ### Deployment
# 1. Environment setup
# 2. Database migration
# 3. Service deployment
# 4. Health check
#
# ## Next Steps
#
# 1. **Initial Setup**
#    - Create project structure
#    - Set up development environment
#    - Implement OAuth2 flow
#
# 2. **Basic Implementation**
#    - Core task operations
#    - Project management
#    - Resource endpoints
#
# 3. **Feature Development**
#    - Time blocking
#    - Checklist management
#    - LLM integration
#
# 4. **Testing and Documentation**
#    - Unit tests
#    - Integration tests
#    - User documentation
#    - API documentation
# Content type: <class 'str'>
# Content length: 29976
# Processing FILE_NAME.md...
# Successfully processed FILE_NAME.md
# Successfully processed 1 files
# Processed files: ['FILE_NAME.md']

# %% [markdown]
# ## Test Document Retrieval

# %%
# Test context retrieval
test_query = "Give the plan for the MCP project?"
context = service.retrieve_context(test_query)

print("Query:", test_query)
print("\nRetrieved Context:")
for chunk in context:
    print(f"\n- {chunk['CHUNK_TEXT']}")
# Out:
# Query: Give the plan for the MCP project?
#
# Retrieved Context:
#
# - # TickTick MCP Server Implementation Plan
#
# ## Overview
# An MCP server implementation that integrates TickTick's task management capabilities with LLM-powered planning and organization features. The server will enable LLMs like Claude to interact with TickTick for creating and managing tasks
#
# ## Core Features
#
# ### 1. Authentication & Setup
# - **OAuth2 Integration**
#   - Implementation: Complex
#   - Priority: High
#   - Components:
#     - OAuth2 flow implementation
#     - Token management and refresh
#     - Secure credential storage
#   - Technical Considerations:
#     - Environment variables for client credentials
#     - Secure token storage
#     - Token refresh handling
#
# - 2. **Update Responsibility:**
#    - The MCP server is responsible for keeping resources up-to-date
#    - Updates happen through:
#      - Regular polling of TickTick API
#      - Response to client subscription requests
#      - After successful tool executions
#      - Background refresh jobs
#
# 3. **Client Notification:**
#    - Clients can subscribe to resource changes
#    - Server sends notifications when resources update
#    - Supported through MCP's `resources.subscribe` capability
#    - Immediate notification of state changes
#
# 4. **Synchronization Flow:**
#    ```
#    TickTick API -> MCP Server -> Resource Cache -> Client Notifications
#    ```
#
# ### Q: What analytics capabilities can be implemented?
# **Confidence: 8/10**
#
# We can implement various analytics features by combining TickTick data with local tracking:
#
# 1. **Task Analytics:**
#    - Completion rates by project/timeframe
#    - Average task duration
#    - Priority distribution
#    - Due date adherence
#    - Task complexity patterns
#
# - 2. Implementation Approach:
#    - Create tasks with specific start/end times
#    - Use task description for block metadata
#    - Leverage priority for block importance
#    - Use projects for block categorization
#
# 3. Additional Metadata:
#    - Store extra timeblock data in local SQLite
#    - Map tasks to timeblock properties
#    - Handle block conflicts locally
#    - Manage block relationships
#
# 4. Limitations:
#    - No native block duration
#    - No direct block visualization
#    - Manual conflict handling needed
#    - Custom UI needed for block view
#
# ### Q: How are MCP resources updated and who manages them?
# **Confidence: 9/10**
#
# Resource updates in MCP follow a specific pattern:
#
# 1. **Update Mechanisms:**
#    - Server-side polling of TickTick API
#    - Webhook support for real-time updates (if TickTick provides them)
#    - Local cache refresh mechanisms
#    - Client subscription notifications

# %% [markdown]
# ## Test RAG with TruLens Monitoring

# %%
# Test complete RAG pipeline
test_queries = [
    "Give the plan for the MCP project?",
]

for query in test_queries:
    
    answer, metadata = service.chat(query)
    print(answer)
# Out:
# Error generating answer: (1409): More than one active session is detected. When you call function 'udf' or use decorator '@udf', you must specify the 'session' parameter if you created multiple sessions.Alternatively, you can use 'session.udf.register' to register UDFs
# Error storing chat message: (1304): 01ba1c20-0004-7b12-0004-b9e300018d56: 001003 (42000): SQL compilation error:
# syntax error line 6 at position 169 unexpected 's'.
# syntax error line 6 at position 217 unexpected 'planning'.
# parse error line 6 at position 351 near '110'.
# parse error line 6 at position 371 near '110'.
# parse error line 6 at position 404 near '110'.
# parse error line 6 at position 459 near '110'.
# parse error line 6 at position 479 near '110'.
# parse error line 6 at position 530 near '110'.
# parse error line 6 at position 566 near '110'.
# parse error line 6 at position 599 near '110'.
# parse error line 6 at position 682 near '110'.
# parse error line 6 at position 710 near '110'.
# parse error line 6 at position 904 near '110'.
# parse error line 6 at position 974 near '110'.
# parse error line 6 at position 1,023 near '110'.
# parse error line 6 at position 1,064 near '110'.
# parse error line 6 at position 1,096 near '110'.
# parse error line 6 at position 1,175 near '110'.
# parse error line 6 at position 1,230 near '110'.
# syntax error line 6 at position 3,979 unexpected 'allowing'.
# syntax error line 6 at position 3,988 unexpected 'for'.
# syntax error line 6 at position 4,075 unexpected 'in'.
# syntax error line 6 at position 4,156 unexpected 'it'.
# syntax error line 6 at position 4,159 unexpected 'is'.
# syntax error line 6 at position 4,352 unexpected 'task'.
# syntax error line 6 at position 4,367 unexpected 'priority'.
# syntax error line 6 at position 4,376 unexpected 'distribution'.
# syntax error line 6 at position 4,390 unexpected 'due'.
# syntax error line 6 at position 4,394 unexpected 'date'.
# syntax error line 6 at position 4,410 unexpected 'and'.
# syntax error line 6 at position 4,482 unexpected 'under'.
# syntax error line 6 at position 4,488 unexpected 'the'.
# parse error line 6 at position 4,506 near '34'.
# syntax error line 6 at position 4,517 unexpected 'it'.
# syntax error line 6 at position 4,520 unexpected 'is'.
# syntax error line 6 at position 4,616 unexpected 'the'.
# parse error line 6 at position 4,634 near '34'.
# syntax error line 6 at position 4,645 unexpected 'it'.
# syntax error line 6 at position 4,648 unexpected 'is'.
# syntax error line 6 at position 4,749 unexpected 'the'.
# parse error line 6 at position 4,767 near '34'.
# syntax error line 6 at position 4,778 unexpected 'it'.
# syntax error line 6 at position 4,781 unexpected 'is'.
# syntax error line 6 at position 4,880 unexpected 'the'.
# parse error line 6 at position 4,898 near '34'.
# syntax error line 6 at position 4,909 unexpected 'it'.
# syntax error line 6 at position 4,912 unexpected 'is'.
# parse error line 6 at position 4,991 near '110'.
# syntax error line 6 at position 5,158 unexpected 'its'.
# syntax error line 6 at position 5,172 unexpected 'implementation'.
# This input had 61 total errors.
# I apologize, but I encountered an error generating the response.

# %% [markdown]
# ## Test Chat History

# %%
# Get chat history for the last conversation
chat_id = metadata['chat_id']
history = service.get_chat_history(chat_id)

print(f"Chat History (ID: {chat_id}):")
for msg in history:
    print(f"\n[{msg['ROLE']}] {msg['CONTENT']}")
    if msg['METADATA']:
        print(f"Metadata: {msg['METADATA']}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Get chat history for the last conversation
# ----> 2 chat_id = metadata['chat_id']
#       3 history = service.get_chat_history(chat_id)
#       5 print(f"Chat History (ID: {chat_id}):")
#
# KeyError: 'chat_id'

# %% [markdown]
# ## Cleanup

# %%
# Remove temporary test file
import os
if os.path.exists(test_file_path):
    os.remove(test_file_path)
    print(f"Removed test file: {test_file_path}")
